# %% [markdown]
# # Merge the Energy Label info with the Solar Potential

# %%
from utils import *

# %% [markdown]
# Define the location for:
# - the directory in which we have the solar potential info
# - the filename in which we have the energy label classification info
# - the subdir in which we will save the combined information
# - the base we will use for creating the filenames of the files in which we will store the combined info

# %%
data_dir = os.path.join(os.getcwd(), 'data')
solar_data_subdir = 'solar_ll'
energy_cls_filename = 'energy_classes_clean.csv'
combined_data_subdir = 'out'
out_base_filename = 'combined_solar_enclass'

# %% [markdown]
# Create the paths

# %%
solar_dir = os.path.join(data_dir, solar_data_subdir)
energy_cls_f = os.path.join(data_dir, energy_cls_filename)
combined_out_dir = os.path.join(data_dir, combined_data_subdir)

# %%
solar_f = [os.path.join(solar_dir, f) for f in os.listdir(solar_dir) if os.path.isfile(os.path.join(solar_dir, f))]
solar_f = sorted(solar_f)

print('We have {} files'.format(len(solar_f)))
# Out:
# We have 33 files

# %% [markdown]
# #### Find the closest location match between the solar potential info and energy label classification info
#
# __Approach__: based on [SciPy's cKDTree](https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.cKDTree.html) on which I stumbled by reviewing the wonderful work presented in this Medium post: [Teaching a neural network to see roads
# ](https://towardsdatascience.com/teaching-a-neural-network-to-see-roads-74bff240c3e5) by Laura Lewis.
#
# What cKDTree does in a nutshell is to find the closest neighbour in dataset A taking dataset B as a basis (you specify through a parameter k for how many closest neighbours to look for for each point in B -- k=1 --> closest neighbour).
#
# To apply this approach to our data we need to do some corrections such that we have 2 datasets (numpy arrays) with point coordinates. The point coordinates should be the ones describing the Latitude and Longitude from the Energy Label Classification dataset and a similar point (centroid - we need to calculate it) for the polygons we have in the Solar Potential dataset.
#
# The corrections we need to make are:
# - Energy Label Classification: reverse the order of the original coordinates from (Long, Lat) to (Lat, Long)
# - Solar Potential:
#     - correct the polygon information such that it conforms to the Linear Ring that Shapely expects when attempting to compute the centroid of a polygon
#     - calculate the centroid

# %%
pool = mp.Pool(mp.cpu_count())
print(pool)

results = pool.map(combine_solar_w_energyclass, \
                   [(solar_f[i], energy_cls_f, combined_out_dir) for i in range(len(solar_f))])
# Out:
# 2019-08-30 05:00:13.966657
# 2019-08-30 05:00:13.966816
# 2019-08-30 05:00:13.967004
# 2019-08-30 05:00:13.967978
# <multiprocessing.pool.Pool object at 0x7f50a8a0c6a0>
# [2019-08-30 05:00:32.778090][/home/osboxes/courses/ibm/data/solar_ll/solar_splitag.csv] ============================
# [2019-08-30 05:00:33.558711][/home/osboxes/courses/ibm/data/solar_ll/solar_splitaa.csv] ============================
# [2019-08-30 05:00:34.382326][/home/osboxes/courses/ibm/data/solar_ll/solar_splitaj.csv] ============================
# [2019-08-30 05:00:34.418455][/home/osboxes/courses/ibm/data/solar_ll/solar_splitad.csv] ============================
# [2019-08-30 05:02:03.475906] Done merging solar and energy class.
# [2019-08-30 05:02:04.734152] Done merging solar and energy class.
# [2019-08-30 05:02:07.635875] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# [2019-08-30 05:02:35.387157] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 399997
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 399337
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 399104
# Done selecting the pair with the minimum distance.         Current total rows: 398863
# Done selecting the pair with the minimum distance.         Current total rows: 399051
# [2019-08-30 05:15:58.479842] Done extracting data from the dictionary columns.
# [2019-08-30 05:16:07.391291] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitaa.csv
# [2019-08-30 05:16:10.936696] Done extracting data from the dictionary columns.
# [2019-08-30 05:16:17.619172] Done extracting data from the dictionary columns.
# [2019-08-30 05:16:19.241872] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitad.csv
# 2019-08-30 05:16:24.001977
# [2019-08-30 05:16:27.559006] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitaj.csv
# 2019-08-30 05:16:53.622213
# 2019-08-30 05:17:08.449612
# [2019-08-30 05:17:20.134900][/home/osboxes/courses/ibm/data/solar_ll/solar_splitae.csv] ============================
# [2019-08-30 05:17:23.030117][/home/osboxes/courses/ibm/data/solar_ll/solar_splitab.csv] ============================
# [2019-08-30 05:17:36.431127][/home/osboxes/courses/ibm/data/solar_ll/solar_splitak.csv] ============================
# [2019-08-30 05:20:25.524110] Done merging solar and energy class.
# [2019-08-30 05:20:34.253916] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# [2019-08-30 05:22:06.498369] Done extracting data from the dictionary columns.
# [2019-08-30 05:22:18.195008] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitag.csv
# [2019-08-30 05:22:37.752527] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398266
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# 2019-08-30 05:27:45.303100
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398937
# [2019-08-30 05:28:14.229944][/home/osboxes/courses/ibm/data/solar_ll/solar_splitah.csv] ============================
# [2019-08-30 05:29:56.123824] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398928
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 399234
# [2019-08-30 05:37:19.860766] Done extracting data from the dictionary columns.
# [2019-08-30 05:37:28.700567] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitae.csv
# [2019-08-30 05:38:22.639765] Done extracting data from the dictionary columns.
# [2019-08-30 05:38:30.083831] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitab.csv
# 2019-08-30 05:38:43.823496
# 2019-08-30 05:38:48.691593
# [2019-08-30 05:39:10.185831][/home/osboxes/courses/ibm/data/solar_ll/solar_splitaf.csv] ============================
# [2019-08-30 05:39:13.829855][/home/osboxes/courses/ibm/data/solar_ll/solar_splitac.csv] ============================
# [2019-08-30 05:41:28.375260] Done extracting data from the dictionary columns.
# [2019-08-30 05:41:36.884451] Done merging solar and energy class.
# [2019-08-30 05:41:37.078453] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitah.csv
# 2019-08-30 05:41:52.374461
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# [2019-08-30 05:42:11.800977][/home/osboxes/courses/ibm/data/solar_ll/solar_splitai.csv] ============================
# [2019-08-30 05:42:24.353224] Done merging solar and energy class.
# [2019-08-30 05:43:37.568892] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398870
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398435
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# [2019-08-30 05:46:12.645698] Done extracting data from the dictionary columns.
# [2019-08-30 05:46:22.952619] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitak.csv
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 399373
# 2019-08-30 05:48:26.455706
# [2019-08-30 05:48:57.593583][/home/osboxes/courses/ibm/data/solar_ll/solar_splital.csv] ============================
# [2019-08-30 05:50:59.046907] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398680
# [2019-08-30 05:56:00.398151] Done extracting data from the dictionary columns.
# [2019-08-30 05:56:09.324518] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitai.csv
# 2019-08-30 05:56:21.866590
# [2019-08-30 05:56:43.414024][/home/osboxes/courses/ibm/data/solar_ll/solar_splitam.csv] ============================
# [2019-08-30 05:57:32.580979] Done extracting data from the dictionary columns.
# [2019-08-30 05:57:47.084042] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitaf.csv
# [2019-08-30 05:58:17.680769] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# [2019-08-30 05:59:16.786263] Done extracting data from the dictionary columns.
# [2019-08-30 05:59:23.920037] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitac.csv
# 2019-08-30 05:59:39.589314
# 2019-08-30 05:59:50.173408
# [2019-08-30 06:00:06.228429][/home/osboxes/courses/ibm/data/solar_ll/solar_splitap.csv] ============================
# [2019-08-30 06:00:13.444458][/home/osboxes/courses/ibm/data/solar_ll/solar_splitas.csv] ============================
# [2019-08-30 06:03:53.057673] Done merging solar and energy class.
# [2019-08-30 06:04:20.950958] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398360
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# [2019-08-30 06:09:08.468857] Done extracting data from the dictionary columns.
# [2019-08-30 06:09:16.607840] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splital.csv
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398543
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398047
# 2019-08-30 06:12:08.152115
# [2019-08-30 06:12:42.156956][/home/osboxes/courses/ibm/data/solar_ll/solar_splitav.csv] ============================
# [2019-08-30 06:14:25.701973] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398014
# [2019-08-30 06:21:00.951825] Done extracting data from the dictionary columns.
# [2019-08-30 06:21:08.515056] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitap.csv
# 2019-08-30 06:21:14.280953
# [2019-08-30 06:21:16.672073] Done extracting data from the dictionary columns.
# [2019-08-30 06:21:25.103757] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitam.csv
# [2019-08-30 06:21:34.234295][/home/osboxes/courses/ibm/data/solar_ll/solar_splitaq.csv] ============================
# [2019-08-30 06:21:40.880180] Done extracting data from the dictionary columns.
# [2019-08-30 06:21:48.126418] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitas.csv
# 2019-08-30 06:21:49.588675
# [2019-08-30 06:22:10.408647][/home/osboxes/courses/ibm/data/solar_ll/solar_splitat.csv] ============================
# [2019-08-30 06:24:39.741796] Done merging solar and energy class.
# 2019-08-30 06:25:57.830764
# [2019-08-30 06:26:44.101182] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# [2019-08-30 06:27:03.599333][/home/osboxes/courses/ibm/data/solar_ll/solar_splitan.csv] ============================
# [2019-08-30 06:28:00.031787] Done extracting data from the dictionary columns.
# [2019-08-30 06:28:21.596816] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitav.csv
# [2019-08-30 06:30:20.890593] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 397896
# 2019-08-30 06:32:52.370842
# [2019-08-30 06:33:15.829171][/home/osboxes/courses/ibm/data/solar_ll/solar_splitaw.csv] ============================
# [2019-08-30 06:35:17.222870] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398913
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 397985
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398398
# [2019-08-30 06:45:39.761708] Done extracting data from the dictionary columns.
# [2019-08-30 06:45:49.453048] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitaq.csv
# [2019-08-30 06:46:07.702407] Done extracting data from the dictionary columns.
# [2019-08-30 06:46:15.654022] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitat.csv
# 2019-08-30 06:46:25.774829
# [2019-08-30 06:46:31.112420] Done extracting data from the dictionary columns.
# [2019-08-30 06:46:38.547493] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitan.csv
# 2019-08-30 06:46:40.253420
# [2019-08-30 06:46:50.506274][/home/osboxes/courses/ibm/data/solar_ll/solar_splitau.csv] ============================
# [2019-08-30 06:46:59.645284][/home/osboxes/courses/ibm/data/solar_ll/solar_splitar.csv] ============================
# 2019-08-30 06:47:03.612226
# [2019-08-30 06:47:11.482396] Done extracting data from the dictionary columns.
# [2019-08-30 06:47:35.132961] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitaw.csv
# [2019-08-30 06:47:40.514663][/home/osboxes/courses/ibm/data/solar_ll/solar_splitao.csv] ============================
# 2019-08-30 06:49:31.052489
# [2019-08-30 06:51:26.937197][/home/osboxes/courses/ibm/data/solar_ll/solar_splitax.csv] ============================
# [2019-08-30 06:52:39.148440] Done merging solar and energy class.
# [2019-08-30 06:54:32.147603] Done merging solar and energy class.
# [2019-08-30 06:54:35.919009] Done merging solar and energy class.
# [2019-08-30 06:55:40.973152] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398623
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398037
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398408
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398338
# [2019-08-30 07:11:49.076211] Done extracting data from the dictionary columns.
# [2019-08-30 07:11:59.662997] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitax.csv
# 2019-08-30 07:12:13.452882
# [2019-08-30 07:12:38.246462][/home/osboxes/courses/ibm/data/solar_ll/solar_splitay.csv] ============================
# [2019-08-30 07:12:47.867331] Done extracting data from the dictionary columns.
# [2019-08-30 07:12:56.344854] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitar.csv
# 2019-08-30 07:13:25.953378
# [2019-08-30 07:13:51.007964][/home/osboxes/courses/ibm/data/solar_ll/solar_splitbb.csv] ============================
# [2019-08-30 07:14:22.473404] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# [2019-08-30 07:15:24.051385] Done extracting data from the dictionary columns.
# [2019-08-30 07:15:31.238784] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitau.csv
# [2019-08-30 07:15:38.967575] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398320
# 2019-08-30 07:17:10.490340
# [2019-08-30 07:17:11.673027] Done extracting data from the dictionary columns.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398472
# [2019-08-30 07:17:20.163282] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitao.csv
# [2019-08-30 07:17:31.320263][/home/osboxes/courses/ibm/data/solar_ll/solar_splitbe.csv] ============================
# [2019-08-30 07:20:01.625027] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 399897
# [2019-08-30 07:26:27.073796] Done extracting data from the dictionary columns.
# [2019-08-30 07:26:33.790056] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitay.csv
# 2019-08-30 07:26:45.122765
# [2019-08-30 07:27:02.486940][/home/osboxes/courses/ibm/data/solar_ll/solar_splitaz.csv] ============================
# [2019-08-30 07:27:05.984307] Done extracting data from the dictionary columns.
# [2019-08-30 07:27:12.743145] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitbb.csv
# 2019-08-30 07:27:17.110683
# [2019-08-30 07:27:33.952986][/home/osboxes/courses/ibm/data/solar_ll/solar_splitbc.csv] ============================
# [2019-08-30 07:28:26.229536] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# [2019-08-30 07:28:53.454708] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398525
# [2019-08-30 07:30:43.930313] Done extracting data from the dictionary columns.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# [2019-08-30 07:30:51.229901] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitbe.csv
# Done selecting the pair with the minimum distance.         Current total rows: 399329
# 2019-08-30 07:30:59.434760
# [2019-08-30 07:31:17.393486][/home/osboxes/courses/ibm/data/solar_ll/solar_splitbf.csv] ============================
# [2019-08-30 07:32:28.532178] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 399923
# [2019-08-30 07:38:34.058783] Done extracting data from the dictionary columns.
# [2019-08-30 07:38:40.479069] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitaz.csv
# 2019-08-30 07:38:41.884415
# [2019-08-30 07:38:58.470103][/home/osboxes/courses/ibm/data/solar_ll/solar_splitba.csv] ============================
# [2019-08-30 07:39:08.552467] Done extracting data from the dictionary columns.
# [2019-08-30 07:39:15.234725] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitbc.csv
# 2019-08-30 07:39:16.714952
# [2019-08-30 07:39:33.282569][/home/osboxes/courses/ibm/data/solar_ll/solar_splitbd.csv] ============================
# [2019-08-30 07:40:12.098205] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# [2019-08-30 07:40:48.325776] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 398464
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 400000
# Done selecting the pair with the minimum distance.         Current total rows: 399917
# [2019-08-30 07:42:28.786285] Done extracting data from the dictionary columns.
# [2019-08-30 07:42:35.981804] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitbf.csv
# 2019-08-30 07:42:37.552589
# [2019-08-30 07:42:53.870463][/home/osboxes/courses/ibm/data/solar_ll/solar_splitbg.csv] ============================
# [2019-08-30 07:43:10.405949] Done merging solar and energy class.
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Index(['pv_prop', 'geometry_sol', 'distance', 'en_prop', 'geometry'], dtype='object')
# Selecting the pair with the minimum distance.         Current total rows: 59735
# Done selecting the pair with the minimum distance.         Current total rows: 59721
# [2019-08-30 07:44:38.935739] Done extracting data from the dictionary columns.
# [2019-08-30 07:44:40.006183] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitbg.csv
# [2019-08-30 07:49:49.012363] Done extracting data from the dictionary columns.
# [2019-08-30 07:49:55.493956] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitba.csv
# [2019-08-30 07:50:15.056445] Done extracting data from the dictionary columns.
# [2019-08-30 07:50:21.596786] Done writing to file: /home/osboxes/courses/ibm/data/out/enclass_solar_splitbd.csv

# %% [markdown]
# #### Refining the closest match
#
# Get the closest solar potential characteristic for each group with the same Address based on the minimm distance.
#
# Back up the results to a file for the actual analysis.

# %%
mydir = os.path.join(os.getcwd(), 'data', 'out')
files = [os.path.join(mydir, f) for f in os.listdir(mydir) if os.path.isfile(os.path.join(mydir, f))]
files = sorted(files)
print('We have {} files'.format(len(files)))

for i in range(len(files)):
    df = pd.read_csv(files[i], sep=';')
    gr_min_dist = df.groupby(['geometry']).agg({'distance':'min'})
    gr_min_dist.reset_index(inplace=True)
    gr_best_match = pd.merge(gr_min_dist, df, on=gr_min_dist.columns.tolist(), how='left')
    filename = files[i].replace('/out/', '/out_clean/')
    gr_best_match.to_csv(filename, sep=';', index=False)
    print('[{}] {}'.format(datetime.now(), filename))

mydir = os.path.join(os.getcwd(), 'data', 'out_clean')
files = [os.path.join(mydir, f) for f in os.listdir(mydir) if os.path.isfile(os.path.join(mydir, f))]

dfs = [pd.read_csv(f, sep=';') for f in files]

consolidated_df = pd.concat(dfs)
consolidated_df.drop_duplicates(inplace=True)
consolidated_df.to_csv('./data/out_clean/consolidated_enclass_solar.csv', sep=';')
